# %%
# !pip install nest_asyncio

import pandas as pd
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
pd.read_csv('ira_tweets_csv_hashed.csv')
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     tweetid  \
# 0        877919995476496385
# 1        492388766930444288
# 2        719455077589721089
# 3        536179342423105537
# 4        841410788409630720
# 5        834365760776630272
# 6        577490527299457024
# 7        596522755379560448
# 8        567357519547207680
# 9        665533117369876480
# 10       493894187079974912
# 11       493688319902220288
# 12       497543470211678209
# 13       701008777001107457
# 14       725740300065366016
# 15       704248884072046592
# 16       710845825622999040
# 17       648955031081758720
# 18       704222907304534016
# 19       860151003752132609
# 20       918116356117139459
# 21       691214524355989504
# 22       840098934777290753
# ...

# %%
df = _ #setting df = to the dataframe from above

# %%
df.columns
# Out:
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_language',
#        'tweet_text', 'tweet_time', 'tweet_client_name', 'in_reply_to_tweetid',
#        'in_reply_to_userid', 'quoted_tweet_tweetid', 'is_retweet',
#        'retweet_userid', 'retweet_tweetid', 'latitude', 'longitude',
#        'quote_count', 'reply_count', 'like_count', 'retweet_count', 'hashtags',
#        'urls', 'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
# df['tweet_language'].unique()

# %%
df_english = df[df['tweet_language']=='en']
df_english.head()
# Out:
#                tweetid                                             userid  \
# 8   567357519547207680  2b0d7525bed1df5119b7956f9be4888b45686172d68006...
# 10  493894187079974912  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 11  493688319902220288  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 12  497543470211678209  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 32  500956712657223680  004c1875a5f3a8ddfd2044b857a81c5d458882ac5cdf67...
#
#                                     user_display_name  \
# 8   2b0d7525bed1df5119b7956f9be4888b45686172d68006...
# 10  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 11  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 12  be1e8e099e93fe0964c1184173f038c7413def3baf38ef...
# 32  004c1875a5f3a8ddfd2044b857a81c5d458882ac5cdf67...
#
#                                      user_screen_name user_reported_location  \
# 8   2b0d7525bed1df5119b7956f9be4888b45686172d68006...             California
# ...

# %%
pd.DataFrame.to_csv(df_english)

# %%
# df_english.isnull().sum()

# %%
# df_english['tweet_text']

# %%
# df['tweet_text']

# %%
# c = twint.Config()
# c.Username = "realDonaldTrump"
# c.Limit = 1
# twint.run.Search(c)

# %%
c = twint.Config()
c.Username = "realDonaldTrump"
c.Limit = 1
c.Pandas = True
c.Store_csv = True
c.Output = 'tweets.csv'
twint.run.Search(c)
df = pd.read_csv('tweets.csv')
# Out:
# 1179023004241727489 2019-10-01 09:19:24 EDT <realDonaldTrump> ....the Whistleblower, and also the person who gave all of the false information to him. This is simply about a phone conversation that could not have been nicer, warmer, or better. No pressure at all (as confirmed by  Ukrainian Pres.). It is just another Democrat Hoax!
# 1179023001989373952 2019-10-01 09:19:23 EDT <realDonaldTrump> So if the so-called “Whistleblower” has all second hand information, and almost everything he has said about my “perfect” call with the Ukrainian President is wrong (much to the embarrassment of Pelosi & Schiff), why aren’t we entitled to interview & learn everything about....
# 1178990430937067520 2019-10-01 07:09:57 EDT <realDonaldTrump> “The congratulatory phone call with the Ukrainian President was PERFECT, unless you heard Liddle’ Adam Schiff’s fraudulently made up version of the call. This is just another Fake News Media, together with their partner, the Democrat Party, HOAX!
# ...

# %%
len(df)
# Out:
# 20

# %%
len(df_english)
# Out:
# 2997181

# %%
c = twint.Config()

c.Limit = 1
c.Pandas = True
c.Store_csv = True
c.Output = 'tweets.csv'
twint.run.Search(c)
df = pd.read_csv('tweets.csv')

# %%
c = twint.Config()

c.Limit = 1
c.Pandas = True
# c.Store_csv = True
# c.Output = 'tweets.csv'
c.Verified = True
c.Format = "Username: {username} |  Tweet: {tweet}"
c.Search = 'politics'
twint.run.Search(c)

# available_columns()

# df_pd = twint_to_pandas(["date", "username", "tweet", "hashtags", "nlikes"])

# %%
c = twint.Config()

c.Limit = 1
c.Pandas = True
c.Verified = True
c.lang = 'en'
c.Format = "Username: {username} |  Tweet: {tweet}"
c.Search = 'conservative'
twint.run.Search(c)
# Out:
# Username: ferretthimself |  Tweet: The reason I like Elizabeth Warren so much is that when people get upset about her plans, she doubles down.  I’m not used to a Democrat who doesn’t flee backwards into the arms of conservative swing voters whenever a CEO gets upset.  https://twitter.com/ewarren/status/1179118101755039744 …
# Username: vanbadham |  Tweet: And now, in translation: Rick, just so you know (because these dudes can’t be [bothered] [learning]; Downer, who [fingered] Papadopoulos, is not only a conservative, but a former conservative CABINET MINISTER. He’s a [conservative elite] who [formerly led] our conservative party.
# Username: NickBoles |  Tweet: Behold Johnson’s Conservative Party.  https://twitter.com/nedsimons/status/1179131574870261760 …
# ...
